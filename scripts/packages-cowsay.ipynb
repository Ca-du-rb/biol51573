# %%
import cowsay

# %%
# get the list of possible characters
# format is: module.function
cowsay.char_names
# Out:
# ['beavis',
#  'cheese',
#  'cow',
#  'daemon',
#  'dragon',
#  'fox',
#  'ghostbusters',
#  'kitty',
#  'meow',
#  'miki',
#  'milk',
#  'octopus',
#  'pig',
#  'stegosaurus',
#  'stimpy',
#  'trex',
#  'turkey',
#  'turtle',
#  'tux']

# %%
cowsay.beavis("Hello, world")
# Out:
#   ____________
# | Hello, world |
# ...
#                  \
#                   \
#                    \
#                          _------~~-,
#                       ,'            ,
#                       /               \\
#                      /                :
#                     |                  '
#                     |                  |
#                     |                  |
#                      |   _--           |
#                      _| =-.     .-.   ||
#                      o|/o/       _.   |
#                      /  ~          \\ |
#                    (____\@)  ___~    |
#                       |_===~~~.`    |
#                    _______.--~     |
#                    \\________       |
#                             \\      |
#                           __/-___-- -__
#                          /            _ \\
